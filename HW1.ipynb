# %%
def vector_dot_product(v1, v2): 
    """
    Computes the dot product of two vectors.
    """
    return sum([v1[i] * v2[i] for i in range(len(v1))])

# the complexity of the code (O notation)
# O(n) = n

# %%
def vector_cross_product(v1, v2): 
    """
    Computes the cross product of two 3D vectors.
    """
    return [v1[1] * v2[2] - v1[2] * v2[1], 
            v1[2] * v2[0] - v1[0] * v2[2], 
            v1[0] * v2[1] - v1[1] * v2[0]]

# the complexity of the code (O notation)
# O(n) = 1 # constant, since it's a fixed 3D calculation

# %%
def matrix_addition(A, B): 
    """
    Adds two matrices of the same size.
    """
    return [[A[i][j] + B[i][j] for j in range(len(A[0]))] for i in range(len(A))]

# the complexity of the code (O notation)
# O(n) = n^2 # complexity for n x n matrices

# %%
def matrix_subtraction(A, B):
    """
    Subtracts matrix B from matrix A, element-wise.
    """
    return [[A[i][j] - B[i][j] for j in range(len(A[0]))] for i in range(len(A))]

# the complexity of the code (O notation)
# O(n) = n^2

# %%
def matrix_product(A, B): 
    """
    Multiplies two matrices.
    """
    return [[sum([A[i][k] * B[k][j] for k in range(len(A[0]))]) for j in range(len(B[0]))] for i in range(len(A))]

# the complexity of the code (O notation)
# O(n) = n^3

# %%
def matrix_vector_product(A, v): 
    """
    Multiplies a matrix by a vector.
    """
    return [sum([A[i][j] * v[j] for j in range(len(v))]) for i in range(len(A))]

# the complexity of the code (O notation)
# O(n) = n^2

# %%
# Use Numpy as well and compare the time it takes to run with both of them.
import numpy as np

A = np.random.rand(100, 100)
B = np.random.rand(100, 100)
v = np.random.rand(100)

# %%
# %%time
print(matrix_product(A, B))
# Out:
# [[26.82825090164807, 25.65956698901396, 25.001142254800754, 25.311559086774274, 24.54914364209593, 25.188166908182968, 27.77360583598822, 26.419341790764594, 23.93084632148025, 27.81312669818056, 27.393094253277187, 25.860015619929666, 25.49065976410143, 24.559187096981024, 27.524958538154372, 24.062019960659672, 24.52267676760085, 28.02991928124332, 30.188941396223225, 26.392319376198373, 25.856533171657247, 27.164237079306513, 25.992885073869704, 25.524791824922005, 27.16137933653115, 25.033117724970932, 24.891901356254753, 25.707661805575988, 26.81838845039762, 26.16227113464774, 25.70272782519398, 27.35223972740848, 24.31481829379455, 26.854615340495926, 25.906945404298412, 25.194449579342468, 24.620069676839226, 26.039734452565572, 27.255752869966432, 26.192383965357035, 26.893744048262686, 26.376238107171417, 25.27774105057996, 28.315786116771815, 22.519843680605714, 26.877160632158876, 26.594536092235778, 27.307638482348263, 28.65102640300734, 24.68484582380962, 26.44579746995687, 25.339239986855826, 26.30771498401869, 24.848468726561062, 26.61965168256519, 28.244914332724303, 27.087298906077685, 24.622288864600613, 23.711063396499625, 23.632541312606897, 23.720433227187318, 25.28810288297461, 26.644075402922518, 28.221489139597903, 23.
#  26.39798172 23.60554209 23.67388129 25.53016008 22.71278988 19.95456778
#  22.86324728 20.44748405 20.81230957 24.49892791 23.01462931 23.14801089
#  22.5285459  24.38449519 21.85983065 25.19917626 25.82998894 22.62888552
#  23.05588929 23.78791405 20.35282964 25.58387143 24.14718013 24.87171169
#  21.06929874 23.23610661 21.85365311 22.44720916 22.49202013 21.84611515
#  25.57429554 23.58743734 23.43824566 24.13819818 21.60148619 22.48039194
#  24.24225925 25.01056763 24.33631115 23.01238118 24.90672103 23.84312173
#  25.04096953 24.79831699 21.01689577 23.31536918 26.25725403 22.13446646
#  26.31206794 20.69862901 24.21526865 19.27692202 22.54898047 22.75286733
#  21.11363879 23.45040753 21.9963715  21.66424052 22.23311119 24.32993006
#  23.1675486  22.66608984 22.15810665 21.47595092 23.11136783 23.24974315
#  24.55895117 23.20864748 22.80808683 20.63659726 21.39478302 21.49603773
#  24.55149892 25.4583532  24.81438924 21.94923242 21.47561051 25.2454503
#  22.48586448 20.03606927 21.87998985 25.12367323]
# CPU times: user 1.84 ms, sys: 636 µs, total: 2.48 ms
# Wall time: 18.7 ms

# %%
# making 2D training data for logistic regression
import numpy as np
import matplotlib.pyplot as plt

n_data = 100
np.random.seed(0)
X = np.random.randn(n_data, 2)
y = np.random.randint(0, 2, n_data)

plt.scatter(X[y == 0, 0], X[y == 0, 1], c='blue', label='0')
plt.scatter(X[y == 1, 0], X[y == 1, 1], c='red', label='1')
plt.xlabel('X1')
plt.ylabel('X2')
plt.legend()
plt.show()

# %%
# We can implement natural logarithm using a Taylor series approximation for log(1+x), 
# but we will use math function in this case

# %%
# Use case 
# Logistic Regression algorithm:

# %%
# In this cell we implement Logistic Regression algorithm without numpy:


# The training process using gradient descent follows these steps:
# 1. Initialize the weights randomly. Start with random values for 𝑤0, 𝑤1, 𝑤2.
w0, w1, w2 = np.random.rand(3)
n_epochs = 100
# 2. For each epoch (iteration over the entire dataset):
for epoch in range(n_epochs):
    # # 1. For each training example (𝑥1, 𝑥2, y):
    for i in range(n_data):
        # # # 1. Compute  𝑧 = 𝑤0 + 𝑤1𝑥1 + 𝑤2𝑥2
        z = w0 + w1 * X[:, 0] + w2 * X[:, 1]
        # # # 2. Apply the sigmoid function to get the predicted probability y_hat = sigmoid(z).
        y_hat = 1 / (1 + np.exp(-z))
        # # # 3. Compute the loss using binary cross-entropy.
        loss = -y * np.log(y_hat) - (1 - y) * np.log(1 - y_hat)
        # # # 4. Compute the gradients for each weight 𝑤0, 𝑤1 ,𝑤2 .
        dw0 = np.mean(y_hat - y)
        dw1 = np.mean((y_hat - y) * X[:, 0])
        dw2 = np.mean((y_hat - y) * X[:, 1])
        # # # 5. Update the weights using gradient descent.
        learning_rate = 0.01
        w0 = w0 - learning_rate * dw0
        w1 = w1 - learning_rate * dw1
        w2 = w2 - learning_rate * dw2
    # # 2. After the epoch, evaluate the performance of the model.
    # # # 1. Compute the accuracy on the training set.
    y_pred = (y_hat > 0.5).astype(int)
    accuracy = np.mean(y_pred == y)
    # # # 2. Compute the loss on the training set.
    loss = np.mean(-y * np.log(y_hat) - (1 - y) * np.log(1 - y_h